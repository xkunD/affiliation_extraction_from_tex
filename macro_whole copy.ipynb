# %%
import tarfile
import io
import zipfile
import importlib
import regex as re
import pyperclip  
import TexSoup as TS
from TexSoup.tokens import MATH_ENV_NAMES
import os

# %%
import pandas as pd
from extractors.trie_extractor import TrieExtractor
from utils.file_reader import read_file
from tqdm import tqdm  # Import tqdm for progress bar

csv_path = "data/2201.00_scopus_931_with_ror.csv"
df = pd.read_csv(csv_path)

# %%
# for shuchang evalutaion
import json
with open("final_affiliations_2000_parallel.json", 'r', encoding='utf-8') as f:
    final_affiliations = json.load(f)

target_file_ids = set(entry['File ID'] for entry in final_affiliations)  # 例如 '2311.00001'

# %%
import zipfile
import re
import io

def find_doc_class(fp, name_match=False):
    """Search for document class related lines in a file and return a code to represent the type"""
    doc_class_pat = re.compile(r"^\s*\\document(?:style|class)")
    sub_doc_class = re.compile(r"^\s*\\document(?:style|class).*(?:\{standalone\}|\{subfiles\})")

    file_content = fp.read()
    try:
        file_text = file_content.decode('utf-8')
    except UnicodeDecodeError:
        file_text = file_content.decode('latin-1')

    for line in file_text.splitlines():
        if doc_class_pat.search(line):
            if name_match:
                if sub_doc_class.search(line):
                    return -99999
                return 1  # Found document class line
    return 0  # No document class line found

def find_main_tex_source_in_folder(zip_file, folder_name):
    """Find the main .tex file inside a folder within the zip archive"""
    tex_names = {"paper", "main", "ms.", "article"}
    
    # Get all .tex files in the folder
    tex_files = [f for f in zip_file.namelist() if f.startswith(folder_name + '/') and f.endswith('.tex')]

    if len(tex_files) == 1:
        return tex_files[0]  # If there's only one .tex file, return it

    main_files = {}
    for tex_file in tex_files:
        depth = tex_file.count('/') - folder_name.count('/')  # Depth relative to folder
        has_main_name = any(kw in tex_file for kw in tex_names)
        
        with zip_file.open(tex_file) as fp:
            main_files[tex_file] = find_doc_class(fp, name_match=has_main_name) - depth

    return max(main_files, key=main_files.get) if main_files else None

def pre_format(text):
    """Format LaTeX text by adding spaces where necessary"""
    # return text.replace('\\}\\', '\\} \\').replace(')}', ') }').replace(')$', ') $')
    return text

def source_from_zip(zip_file, folder_name):
    """Extract and decode the main .tex file from a folder inside the zip archive"""
    tex_main = find_main_tex_source_in_folder(zip_file, folder_name)
    if tex_main:
        with zip_file.open(tex_main) as fp:
            file_content = fp.read()
            try:
                source_text = pre_format(file_content.decode('utf-8'))
            except UnicodeDecodeError:
                source_text = pre_format(file_content.decode('latin-1'))
            return source_text
    return None

def extract_before_abstract(source_text):
    """Extract text before the abstract section"""
    no_comments_text = re.sub(r'(?<!\\)%.*', '', source_text)  # Remove comments
    # no_usepackage_text = re.sub(r'\\usepackage\s*\{[^}]+\}', '', no_comments_text)  # Remove usepackage
    # text = re.sub(r'\\[a-zA-Z]+\{[^}]*\}', '', no_usepackage_text)  # Remove LaTeX commands
    text = no_comments_text
    # text = re.sub(r'\\[a-zA-Z]+\[[^\]]*\]\{[^}]*\}', '', text)
    # text = re.sub(r'\$[^$]*\$', '', text)  # Remove inline math
    # text = text.replace('{', '').replace('}', '').replace('\n', ' ')
    text = ' '.join(text.split())

    # output_file.write(f"text: {text}\n")

    abstract_word_match = re.search(r'begin{abstract}', text, re.IGNORECASE)
    if abstract_word_match:
        return text[:abstract_word_match.start()].strip()

    abstract_match = re.search(r'abstract{', text)
    if abstract_match:
        return text[:abstract_match.start()].strip()
    
    nomacro_abstract_match_2 = re.search(r'abstract', text)
    if nomacro_abstract_match_2:
        return text[:nomacro_abstract_match_2.start()].strip()
    
    nomacro_abstract_match_1 = re.search(r'Abstract', text)
    if nomacro_abstract_match_1:
        return text[:nomacro_abstract_match_1.start()].strip()
    
    one_third_length = len(text) // 3
    return text[:one_third_length].strip()

zip_file_path = "./2311_tex.zip"
output_path = "./output.txt"


with zipfile.ZipFile(zip_file_path, 'r') as zip_file:
    base_folder = zip_file.namelist()[0]    
    folders = {name.rstrip('/') for name in zip_file.namelist() if name.startswith(base_folder) and name.endswith('/') and name != base_folder}
    filtered_folders = {folder for folder in folders if folder.split('/')[-1] in target_file_ids}

    with open(output_path, 'w', encoding='utf-8') as output_file:
        for folder in filtered_folders:
            source_text = source_from_zip(zip_file, folder)
            # output_file.write(f"{folder}:source text: {source_text}\n")
            if source_text:
                content_before_abstract = extract_before_abstract(source_text)
                if content_before_abstract:
                    output_file.write(f"Content before abstract in {folder}:\n{content_before_abstract}\n\n")
                else:
                    output_file.write(f"No abstract found in {folder}, or no content before abstract.\n\n")
            else:
                output_file.write(f"No source found in {folder}.\n\n")

# %%
# Read input from a text file and filter out files without valid content before the abstract
input_file_path = 'output.txt'  # Replace with your actual file path
output_file_path = 'filtered_files_with_content_macro.txt'

# Variables to keep track of statistics
total_files_count_author = 0
valid_files_count = 0
valid_files_with_content = []

# Reading and processing the input file
with open(input_file_path, 'r') as infile:
    content_blocks = infile.read().split('Content before abstract in ')
    
    for block in content_blocks:
        if block.strip():  # Ensure we are not processing an empty block
            total_files_count_author += 1
            lines = block.split('\n', 1)  # Split to separate the file name from its content
            if len(lines) > 1:
                file_name = lines[0].strip().replace(':', '')
                content = lines[1].strip()
                
                # Check if the content does not indicate "No abstract found"
                if 'No abstract found' not in content and 'no content before abstract' not in content.lower():
                    valid_files_count += 1
                    valid_files_with_content.append((file_name, content))

# Writing the filtered results to an output file
with open(output_file_path, 'w') as outfile:
    for file_name, content in valid_files_with_content:
        outfile.write(f"Content before abstract in {file_name}:\n{content}\n\n")

# Print or save the statistics summary
print(f"Total number of files processed: {total_files_count_author}")
print(f"Total number of files with valid content before abstract: {valid_files_count}")
print(f"Filtered output saved in: {output_file_path}")
# Out:
# Total number of files processed: 1998
# Total number of files with valid content before abstract: 1996
# Filtered output saved in: filtered_files_with_content_macro.txt

# %%
import re
import os
import json  # For structured storage

# Define file paths
input_file_path = 'filtered_files_with_content_macro.txt'
output_file_path = './tagged_outputs/all_extracted_tags_cleaned.txt'  # Single output file

# Ensure output directory exists
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

# Tags to search for (without leading backslashes for dictionary keys)
tags_to_search = [
    'orgname','institution', 'affiliations', 'affiliation', 'icmlaffiliation',
    'institute', 'affil', 'aff', 'AFF', 'university', 'address'
]

# Dictionary to store extracted data
extracted_data = {}

# Function to extract content inside the first level of braces `{}` (handling optional `[]`)
def extract_tag_content(tag, content):
    pattern = rf"(\\{tag})(\[[^\]]*\])?\{{"
    results = []
    start = 0

    while (match := re.search(pattern, content[start:])) is not None:
        start_idx = start + match.end()  # Start after the macro (past `{`)
        brace_level = 1
        end_idx = start_idx

        # Find the matching closing brace
        while brace_level > 0 and end_idx < len(content):
            if content[end_idx] == '{':
                brace_level += 1
            elif content[end_idx] == '}':
                brace_level -= 1
            end_idx += 1

        # Extract only the content inside the first `{}` (excluding the macro name)
        extracted_content = content[start_idx:end_idx - 1].strip()  # Remove trailing `}`
        results.append(extracted_content)
        start = end_idx  # Move to next occurrence

    return results

# Function to process and store extracted content
def extract_and_store_tags(file_name, content, tags):
    extracted_data[file_name] = {}  # Initialize storage for this file
    found_any_tag = False  # Flag to check if we found any tag

    for tag in tags:
        matches = extract_tag_content(tag, content)

        if matches:
            extracted_data[file_name][tag] = matches  # Store under cleaned key
            found_any_tag = True  # At least one macro was found
            break

    # If no macros were found, store the whole pre-abstract content
    if not found_any_tag:
        extracted_data[file_name]["full_content"] = content

# Process input file
total_files_count = 0

with open(input_file_path, 'r') as infile:
    content_blocks = infile.read().split('Content before abstract in ')

    for block in content_blocks:
        if block.strip():
            total_files_count += 1
            lines = block.split('\n', 1)

            if len(lines) > 1:
                file_name = lines[0].strip().replace(':', '')
                content = lines[1].strip()
                extract_and_store_tags(file_name, content, tags_to_search)

json_output = json.dumps(extracted_data, indent=4, ensure_ascii=False)
# json_output = json_output.replace("\\\\", "\\")  # Convert double backslashes to single

with open(output_file_path, 'w', encoding='utf-8') as outfile:
    outfile.write(json_output)


# Print summary
print(f"Total number of files processed: {total_files_count}")
print(f"Extracted tag data saved in: {output_file_path}")
# Out:
# Total number of files processed: 1996
# Extracted tag data saved in: ./tagged_outputs/all_extracted_tags_cleaned.txt

# %%
import requests
import json
import logging
import os
from tenacity import retry, stop_after_attempt, wait_fixed

# Configure logging
logging.basicConfig(level=logging.INFO)

# Configure ROR API information
ROR_SEARCH_URL = 'https://api.ror.org/organizations'

# Initialize ROR cache
ror_cache = {}

# Load persistent cache
cache_file = 'ror_cache.json'
if os.path.exists(cache_file):
    with open(cache_file, 'r', encoding='utf-8') as f:
        ror_cache = json.load(f)
    logging.info("Loaded persistent ROR cache.")
else:
    logging.info("No persistent ROR cache found. Using empty cache.")

@retry(stop=stop_after_attempt(3), wait=wait_fixed(5))
def query_ror(institution_name):
    """
    Query ROR information, returning best match from top 3 candidates.
    """
    if institution_name in ror_cache:
        return ror_cache[institution_name]

    params = {'query': institution_name}

    try:
        response = requests.get(ROR_SEARCH_URL, params=params, timeout=10)
        if response.status_code == 200:
            data = response.json()
            items = data.get('items', [])
            
            if not items:
                logging.warning(f"No ROR information found for '{institution_name}'.")
                ror_cache[institution_name] = None
                return None

            # Only consider top 3 results
            candidates = items[:3]
            chosen = None

            logging.info(f"🔍 Query: {institution_name}")
            for idx, item in enumerate(candidates):
                candidate_name = item.get('name', '').lower()
                if candidate_name in institution_name.lower():
                    chosen = item
                    logging.info(f"✅ Match found with candidate {idx+1}: {item.get('name')}")
                    break
                else:
                    logging.info(f"❌ No match for candidate {idx+1}: {item.get('name')}")

            if not chosen:
                # Fallback: take first one
                chosen = candidates[0]
                logging.info(f"⚠️ No match found, fallback to first candidate: {chosen.get('name')}")

            ror_cache[institution_name] = {
                'ROR_ID': chosen.get('id', 'N/A'),
                'Name': chosen.get('name', 'N/A'),
                'Country': chosen.get('country', {}).get('country_name', 'N/A'),
                'Type': ', '.join(chosen.get('types', []))
            }
            return ror_cache[institution_name]

        else:
            logging.error(f"ROR API query failed with status code: {response.status_code} for institution: {institution_name}")
            ror_cache[institution_name] = None
            return None

    except Exception as e:
        logging.error(f"ROR API query exception for '{institution_name}', Error: {e}")
        ror_cache[institution_name] = None
        return None

# Save cache to a file after all queries
def save_cache():
    with open(cache_file, 'w', encoding='utf-8') as f:
        json.dump(ror_cache, f)
    logging.info("Saved ROR cache to file.")
# Out:
# INFO:root:Loaded persistent ROR cache.

# %%
import json
import os
from extractors.trie_extractor import TrieExtractor
from utils.file_reader import read_file

# Define file paths
input_file_path = 'tagged_outputs/all_extracted_tags_cleaned.txt'
output_file_path = 'institution_output_with_ror.json'

# Read the file and replace invalid escape sequences
with open(input_file_path, 'r', encoding='utf-8') as infile:
    raw_data = infile.read()

# Fix invalid escape sequences by double-escaping backslashes
# fixed_data = raw_data.replace("\\", "\\\\")
fixed_data = raw_data

# Try loading again
try:
    extracted_data = json.loads(fixed_data)
    print("✅ JSON successfully loaded!")
except json.JSONDecodeError as e:
    print(f"❌ JSON loading failed: {e}")
# Out:
# ✅ JSON successfully loaded!

# %%
# Load TrieExtractor for full content/address processing
extractor = TrieExtractor(
    data_path="data/1.34_extracted_ror_data.csv",
    common_words_path="data/common_english_words.txt"
)

# %%
import re
import spacy
# Load the spaCy model for Named Entity Recognition (NER)
nlp = spacy.load("en_core_web_sm")

# %%
def remove_address_spacy(text):
    """Uses spaCy NER to remove location entities from an institution name"""
    doc = nlp(text)
    cleaned_parts = []
    
    for ent in doc.ents:
        if ent.label_ in {"GPE", "LOC"}:  # GPE = Geo-Political Entity (City, Country, etc.)
            continue  # Skip locations
        cleaned_parts.append(ent.text)

    return " ".join(cleaned_parts)

# %%
import re
from pylatexenc.latex2text import LatexNodes2Text

converter = LatexNodes2Text()

def remove_address_spacy(text):
    """Uses spaCy NER to remove location entities from an institution name"""
    doc = nlp(text)
    cleaned_parts = []

    for ent in doc.ents:
        if ent.label_ in {"GPE", "LOC"}:
            continue  # Skip locations
        cleaned_parts.append(ent.text)

    return " ".join(cleaned_parts)

def latex_to_unicode(text):
    """Safely converts LaTeX special characters to Unicode, handling errors."""
    if not text or text.strip() == "":
        return ""  # Avoid empty input issues

    try:
        return converter.latex_to_text(text)
    except IndexError as e:
        print(f"⚠️ Warning: Error parsing LaTeX in text: {text}")
        print("\n⚠️ latex_to_unicode parse error encountered!")
        print("Full input string:")
        print("--------------------------------------------------")
        print(text)
        print("--------------------------------------------------")
        print(f"Error message: {e}\n")
        return text  # fallback: just return the original text

def mild_clean_affiliation(affiliation):
    parts = [p.strip() for p in affiliation.split(',')]
    if len(parts) > 3:
        for i, part in enumerate(parts):
            if 'university' in part.lower():
                if i < len(parts) - 1:
                    return f"{part}, {part}, {parts[i+1]}"
                else:
                    return part
        affiliation = ', '.join(parts[:3])
    return affiliation.strip()


import re

def split_affiliations_before_unicode(text):
    # 1. 预处理: 兼容一些奇怪的latex写法，比如\$^\dag\$ 这种
    text = text.replace('\\$', '$').replace('\\\\', '\\')
    
    # 2. 正则表达式：匹配 $^*  $^\dag$  $^1$ 这种开头
    pattern = re.compile(r'\$\\?\^\s*(?:\d+|\\dag|\\star|\*)\$?')
    
    # 找到所有匹配的位置
    matches = list(pattern.finditer(text))

    # 如果没有找到任何分割标记，直接返回整体
    if not matches:
        return [text.strip()]

    # 根据匹配位置进行切割
    results = []
    last_end = 0
    for match in matches:
        start = match.start()
        if start > last_end:
            chunk = text[last_end:start].strip()
            if chunk:
                results.append(chunk)
        last_end = match.end()

    # 处理最后一段
    if last_end < len(text):
        chunk = text[last_end:].strip()
        if chunk:
            results.append(chunk)

    return results



def smart_pick_best_ror(query_text, candidates):
    """Choose the best matching ROR result based on exact match priority."""
    for idx, item in enumerate(candidates):
        name = item.get('name', '').lower()
        if name and name in query_text.lower():
            print(f"✅ Match found with candidate {idx+1}: {name}")
            return item
        else:
            print(f"❌ No match for candidate {idx+1}: {name}")
    print("⚠️ No candidate matched exactly, fallback to first.")
    return candidates[0] if candidates else None


    
stringa1 = r"$^*$Physics Department, Arizona State University, Tempe, Arizona 85287, USA. \\ $^\\dag$Theoretical Physics Department, CERN, 1211 Geneva 23, Switzerland."
stringa2 = r"$^1$ Robotics and Artificial Intelligence Group, Department of Computer Science, Electrical and Space Engineering, Lule\\aa \,\, University of Technology, Sweden (e-mail: (vissan, sumsat, geonik)@ltu.se) \\ $^2$ Department of Computer Science, University of Helsinki, Finland."

print("\nOriginal input:")
print(stringa2)

split_result = split_affiliations_before_unicode(stringa2)

print("\nSplit affiliations before unicode:")
for idx, aff in enumerate(split_result, 1):
    print(f"Institution {idx}: {aff}")
# Out:
# Original input:
# $^1$ Robotics and Artificial Intelligence Group, Department of Computer Science, Electrical and Space Engineering, Lule\\aa \,\, University of Technology, Sweden (e-mail: (vissan, sumsat, geonik)@ltu.se) \\ $^2$ Department of Computer Science, University of Helsinki, Finland.
#
# Split affiliations before unicode:
# Institution 1: Robotics and Artificial Intelligence Group, Department of Computer Science, Electrical and Space Engineering, Lule\aa \,\, University of Technology, Sweden (e-mail: (vissan, sumsat, geonik)@ltu.se) \
# Institution 2: Department of Computer Science, University of Helsinki, Finland.

# %%
results = {}

# Process each paper
for paper, macros in extracted_data.items():
    unique_rors = {}

    if isinstance(macros, dict) and set(macros.keys()) in [{"full_content"}, {"address"}]:
        text = "\n".join(macros.get("full_content", [])) + "\n" + "\n".join(macros.get("address", []))
        text = latex_to_unicode(text)
        extracted_ror_ids = extractor.extract_affiliations(text)

        if extracted_ror_ids:
            unique_rors.update({ror_id: {"ROR_ID": ror_id} for ror_id in extracted_ror_ids})

    else:
        for content_list in macros.values():
            for institution_name in content_list:
                
                raw_institutions = re.split(r'(?:\\\\)?\\and', institution_name)

                for raw_inst in raw_institutions:
                    raw_inst = raw_inst.strip()

                    split_by_superscript = re.split(r'\s*\^\d+', raw_inst)
                    split_by_superscript = [inst.strip() for inst in split_by_superscript if inst.strip()]

                    for raw_piece in split_by_superscript:
                        if not raw_piece:
                            continue

                        cleaned_piece = latex_to_unicode(raw_piece)

                        cleaned_piece = cleaned_piece.replace("{", " ").replace("}", " ").replace("^", " ").replace("[", " ").replace("]", " ").strip()
                        cleaned_piece = mild_clean_affiliation(cleaned_piece)
                        cleaned_piece = re.sub(r'^(.*?\b(Department of|School of|Faculty of|College of|Department)\b[^,]*),', '', cleaned_piece, flags=re.IGNORECASE)

                        if cleaned_piece:
                            ror_info = query_ror(cleaned_piece)
                            if ror_info:
                                unique_rors[ror_info["ROR_ID"]] = ror_info  # Store unique RORs

    if unique_rors:
        results[paper] = list(unique_rors.values())

with open(output_file_path, 'w', encoding='utf-8') as outfile:
    json.dump(results, outfile, indent=4, ensure_ascii=False)

print(f"✅ JSON export completed. Results saved to {output_file_path}")
# Out:
# INFO:root:🔍 Query: addressline=The University of Manchester, addressline=The University of Manchester, city=Manchester
# INFO:root:✅ Match found with candidate 1: University of Manchester
# INFO:root:🔍 Query: addressline=Chulalongkorn University, addressline=Chulalongkorn University, city=Bangkok
# INFO:root:✅ Match found with candidate 1: Chulalongkorn University
# INFO:root:🔍 Query: Denison University, Denison University, Granville
# INFO:root:✅ Match found with candidate 1: Denison University
# INFO:root:🔍 Query: Crimean Astrophysical Observatory, 298409 Nauchny, Crimea
# INFO:root:✅ Match found with candidate 1: Crimean Astrophysical Observatory
# INFO:root:🔍 Query: Shanghai Jiao Tong University, Shanghai Jiao Tong University, 800 Dongchuan Road
# INFO:root:✅ Match found with candidate 1: Shanghai Jiao Tong University
# INFO:root:🔍 Query: Ningxia University, Ningxia University, Yinchuan
# INFO:root:✅ Match found with candidate 1: Ningxia University
# INFO:root:🔍 Query: Shanghai Research Center for Quantum Sciences, Shanghai 201315, China
# INFO:root:❌ No match for candidate 1: Shanghai Supercomputer Center (China)
# INFO:root:❌ No match for candidate 2: Shanghai Chengtou (China)
# INFO:root:❌ No match for candidate 3: Shanghai Electric (China)
# INFO:root:⚠️ No match found, fallback to first candidate: Shanghai Supercomputer Center (China)
# INFO:root:🔍 Query: Shandong Normal University, Shandong Normal University, Jinan 250358
# INFO:root:✅ Match found with candidate 1: Shandong Normal University
# WARNING:root:No ROR information found for 'Jiangwei Wu: wjw2016@sjtu.edu.cn'.
# WARNING:root:No ROR information found for 'Xiongshuo Yan: xiongshuoyan@sjtu.edu.cn'.
# WARNING:root:No ROR information found for 'Xueyi Wang: wangxytrish@sjtu.edu.cn'.
# WARNING:root:No ROR information found for 'Tingge Yuan: yuantg0516@sjtu.edu.cn'.
# WARNING:root:No ROR information found for 'Chengyu Chen: chengyuchen@sjtu.edu.cn'.
# INFO:root:🔍 Query: Hao Li: lihaosky@sjtu.edu.cn
# INFO:root:❌ No match for candidate 1: High Altitude Observatory
# INFO:root:⚠️ No match found, fallback to first candidate: High Altitude Observatory
# WARNING:root:No ROR information found for 'Xianfeng Chen: xfchen@sjtu.edu.cn'.
# INFO:root:🔍 Query: Yuping Chen *: ypchen@sjtu.edu.cn
# INFO:root:❌ No match for candidate 1: Ten Chen Hospital
# INFO:root:⚠️ No match found, fallback to first candidate: Ten Chen Hospital
# INFO:root:🔍 Query:  Shanghai Jiao Tong University,
# INFO:root:✅ Match found with candidate 1: Shanghai Jiao Tong University
# INFO:root:🔍 Query: 800 Dongchuan Road, Shanghai 200240, China
# INFO:root:❌ No match for candidate 1: Shanghai Electric (China)
# INFO:root:❌ No match for candidate 2: Shanghai Liangyou (China)
# INFO:root:❌ No match for candidate 3: Shanghai Chengtou (China)
# INFO:root:⚠️ No match found, fallback to first candidate: Shanghai Electric (China)
# ERROR:root:ROR API query failed with status code: 500 for institution: Tel: +86-13816373910
# INFO:root:🔍 Query: These authors contributed equally to this work.
# INFO:root:❌ No match for candidate 1: Then Try This
# INFO:root:❌ No match for candidate 2: Textbook and Academic Authors Association
# INFO:root:❌ No match for candidate 3: Vessel Work
# INFO:root:⚠️ No match found, fallback to first candidate: Then Try This
# INFO:root:🔍 Query: Aryabhatta Research Institute of Observational sciencES (ARIES), Manora Peak, Nainital
# INFO:root:✅ Match found with candidate 1: Aryabhatta Research Institute of Observational Sciences
# INFO:root:🔍 Query: University of Calcutta, University of Calcutta, Kolkata
# INFO:root:✅ Match found with candidate 1: University of Calcutta
# INFO:root:🔍 Query: Deen Dayal Upadhyaya Gorakhpur University, Deen Dayal Upadhyaya Gorakhpur University, Gorakhpur
# INFO:root:✅ Match found with candidate 1: Deen Dayal Upadhyaya Gorakhpur University
# INFO:root:🔍 Query: National University of Uzbekistan, National University of Uzbekistan, Department of Astronomy and Astrophysics
# INFO:root:✅ Match found with candidate 1: National University of Uzbekistan
# INFO:root:🔍 Query: Ulugh Beg Astronomical Institute of the Uzbek Academy of Sciences, Astronomicheskaya 33, 100052 Tashkent
# INFO:root:✅ Match found with candidate 1: Ulugh Beg Astronomical Institute
# INFO:root:🔍 Query:  Université Laval, 2325
# INFO:root:✅ Match found with candidate 1: Université Laval
# INFO:root:🔍 Query: Mahatma Jyotiba Phule Rohilkhand University, Mahatma Jyotiba Phule Rohilkhand University, Bareilly
# INFO:root:❌ No match for candidate 1: M.J.P. Rohilkhand University
# INFO:root:❌ No match for candidate 2: Mahatma Phule Krishi Vidyapeeth
# INFO:root:❌ No match for candidate 3: Savitribai Phule Pune University
# INFO:root:⚠️ No match found, fallback to first candidate: M.J.P. Rohilkhand University
# INFO:root:🔍 Query: University of British Columbia, University of British Columbia, 6224 Agricultural Road
# INFO:root:✅ Match found with candidate 1: University of British Columbia
# INFO:root:🔍 Query: University of Liège, University of Liège, Allée du 6 Août 19c
# INFO:root:✅ Match found with candidate 1: University of Liège
# INFO:root:🔍 Query: Guangzhou University, Guangzhou University, Guangzhou 510006
# INFO:root:✅ Match found with candidate 1: Guangzhou University
# INFO:root:🔍 Query: Instituto de Física de São Carlos, Universidade de São Paulo - 13566-590 São Carlos, SP
# INFO:root:❌ No match for candidate 1: Universidade Federal de São Carlos
# INFO:root:✅ Match found with candidate 2: Universidade de São Paulo
# INFO:root:🔍 Query: Université Côte d'Azur, CNRS, INPHYNI
# INFO:root:✅ Match found with candidate 1: Université Côte d'Azur
# INFO:root:🔍 Query: Departamento de Física, Universidade Federal de São Carlos, Rodovia Washington Luís
# INFO:root:✅ Match found with candidate 1: Universidade Federal de São Carlos
# INFO:root:🔍 Query: Center for Theoretical Physics
#  Massachusetts Institute of Technology, Cambridge, MA 02139
# INFO:root:✅ Match found with candidate 1: Center for Theoretical Physics
# INFO:root:🔍 Query: University of Tokyo, University of Tokyo, Kashiwa
# INFO:root:❌ No match for candidate 1: Tokyo University of Agriculture
# INFO:root:❌ No match for candidate 2: Tokyo University of Technology
# INFO:root:❌ No match for candidate 3: The University of Tokyo
# INFO:root:⚠️ No match found, fallback to first candidate: Tokyo University of Agriculture
# INFO:root:🔍 Query: University of Florida, University of Florida, Department of Physics
# INFO:root:✅ Match found with candidate 1: University of Florida
# INFO:root:🔍 Query: National Institute of Chemical Physics and Biophysics (NICPB), Rävala pst 10, 10143 Tallinn
# INFO:root:✅ Match found with candidate 1: National Institute of Chemical Physics and Biophysics
# INFO:root:🔍 Query: Instituto de Estudios Astrofísicos, Facultad de Ingeniería y Ciencias, Universidad Diego Portales
# INFO:root:❌ No match for candidate 1: Diego Portales University
# INFO:root:❌ No match for candidate 2: Universidad de Ingeniería y Tecnología
# INFO:root:❌ No match for candidate 3: Instituto de Ingeniería
# INFO:root:⚠️ No match found, fallback to first candidate: Diego Portales University
# INFO:root:🔍 Query: Peking University, Peking University, Beijing 100871
# INFO:root:✅ Match found with candidate 1: Peking University
# INFO:root:🔍 Query: Tohoku University, Tohoku University, Sendai
# INFO:root:✅ Match found with candidate 1: Tohoku University
# INFO:root:🔍 Query: Astronomical Observatory, Volgina 7, 11060 Belgrade
# INFO:root:✅ Match found with candidate 1: Astronomical Observatory
# INFO:root:🔍 Query: Sterrenkundig Observatorium, Universiteit Ghent, Krijgslaan 281 S9
# INFO:root:❌ No match for candidate 1: Ghent University
# INFO:root:❌ No match for candidate 2: Thüringer Landessternwarte Tautenburg
# INFO:root:❌ No match for candidate 3: Trieste Astronomical Observatory
# INFO:root:⚠️ No match found, fallback to first candidate: Ghent University
# INFO:root:🔍 Query: RIKEN Cluster for Pioneering Research, 2-1 Hirosawa, Wako
# INFO:root:❌ No match for candidate 1: Wako University
# INFO:root:✅ Match found with candidate 2: RIKEN
# INFO:root:🔍 Query: Kyoto University, Kyoto University, Kitashirakawa -Oiwake-cho
# INFO:root:✅ Match found with candidate 1: Kyoto University
# INFO:root:🔍 Query: University of Maryland, University of Maryland, College Park
# INFO:root:✅ Match found with candidate 1: University of Maryland, College Park
# INFO:root:🔍 Query: National Radio Astronomy Observatory, 520 Edgemont Road, Charlottesville
# INFO:root:✅ Match found with candidate 1: National Radio Astronomy Observatory
# INFO:root:🔍 Query: University of Florida, University of Florida, P.O. Box 112055
# INFO:root:✅ Match found with candidate 1: University of Florida
# INFO:root:🔍 Query: Eureka Scientific, 2452 Delmer Street Suite 100, Oakland
# INFO:root:✅ Match found with candidate 1: Eureka Scientific
# INFO:root:🔍 Query: Space Science Institute, 4750 Walnut Street, Suite 205
# INFO:root:✅ Match found with candidate 1: Space Science Institute
# INFO:root:🔍 Query: Tel Aviv University, Tel Aviv University, Tel Aviv 69978
# INFO:root:✅ Match found with candidate 1: Tel Aviv University
# INFO:root:🔍 Query: Institute of Astronomy, Madingley Road, Cambridge CB3 0HA
# INFO:root:✅ Match found with candidate 1: Institute of Astronomy
# INFO:root:🔍 Query: University of Southampton, University of Southampton, Southampton
# INFO:root:✅ Match found with candidate 1: University of Southampton
# INFO:root:🔍 Query: Gymnasium Schwarzenbek, 21493 Schwarzenbek, Germany
# INFO:root:❌ No match for candidate 1: Holbein-Gymnasium Augsburg
# INFO:root:❌ No match for candidate 2: Gymnasium am Münsterplatz
# INFO:root:❌ No match for candidate 3: Christelijk Gymnasium Utrecht
# INFO:root:⚠️ No match found, fallback to first candidate: Holbein-Gymnasium Augsburg
# INFO:root:🔍 Query: Instituto de Astrofísica, Facultad de Física, Pontificia Universidad Católica de Chile
# INFO:root:✅ Match found with candidate 1: Pontificia Universidad Católica de Chile
# INFO:root:🔍 Query: Centro de Astroingeniería, Facultad de Física, Pontificia Universidad Católica de Chile
# INFO:root:✅ Match found with candidate 1: Pontificia Universidad Católica de Chile
# INFO:root:🔍 Query: Millennium Institute of Astrophysics, Nuncio Monseñor Sótero Sanz 100, Of 104
# INFO:root:✅ Match found with candidate 1: Millennium Institute of Astrophysics
# INFO:root:🔍 Query: Joint ALMA Observatory, Avenida Alonso de Cordova 3107, Vitacura 7630355
# INFO:root:❌ No match for candidate 1: University of Córdoba
# INFO:root:❌ No match for candidate 2: Alberta Livestock and Meat Agency
# INFO:root:✅ Match found with candidate 3: Alma
# INFO:root:🔍 Query: STAR Institute, Quartier Agora - Allée du six Août, 19c B-4000 Liège
# INFO:root:❌ No match for candidate 1: Hôpital 20 Août
# INFO:root:❌ No match for candidate 2: Centre de recherche multidisciplinaire en sciences humaines et sociales
# INFO:root:✅ Match found with candidate 3: Agora
# INFO:root:🔍 Query: Korea Astronomy & Space Science institute, 776, Daedeokdae-ro
# INFO:root:❌ No match for candidate 1: Korea Astronomy and Space Science Institute
# INFO:root:❌ No match for candidate 2: Astronomy and Space
# INFO:root:✅ Match found with candidate 3: Space Science Institute
# INFO:root:🔍 Query: Stanford University, Stanford University, 452 Lomita Mall
# INFO:root:✅ Match found with candidate 1: Stanford University
# INFO:root:🔍 Query: Stanford University, Stanford University, 382 Via Pueblo Mall
# INFO:root:✅ Match found with candidate 1: Stanford University
# INFO:root:🔍 Query: X-ray Astrophysics Laboratory, NASA Goddard Space Flight Center, Code 662
# INFO:root:✅ Match found with candidate 1: Goddard Space Flight Center
# INFO:root:🔍 Query: Oak Ridge Associated Universities, NASA NPP Program, Oak Ridge
# INFO:root:✅ Match found with candidate 1: Oak Ridge Associated Universities
# INFO:root:🔍 Query: Centro de Astronomía (CITEVA), Universidad de Antofagasta, Avenida Angamos 601
# INFO:root:❌ No match for candidate 1: University of Antofagasta
# INFO:root:❌ No match for candidate 2: Instituto de Geofísica y Astronomía
# INFO:root:❌ No match for candidate 3: Museu de Astronomia e Ciências Afins
# INFO:root:⚠️ No match found, fallback to first candidate: University of Antofagasta
# INFO:root:🔍 Query: Dipartimento di Matematica e Fisica, Universita Roma Tre, via della Vasca Navale 84
# INFO:root:❌ No match for candidate 1: Istituto Nazionale di Fisica Nucleare, Sezione di Roma Tre
# INFO:root:❌ No match for candidate 2: Roma Tre University
# INFO:root:❌ No match for candidate 3: Sapienza University of Rome
# INFO:root:⚠️ No match found, fallback to first candidate: Istituto Nazionale di Fisica Nucleare, Sezione di Roma Tre
# INFO:root:🔍 Query: National Astronomical Observatory of Japan, 2-21-1 Osawa, Mitaka
# INFO:root:✅ Match found with candidate 1: National Astronomical Observatory of Japan
# ERROR:root:ROR API query failed with status code: 500 for institution: Academia Sinica Institute of Astronomy and Astrophysics, 11F Astronomy-Mathematics Building, AS/NTU
# INFO:root:🔍 Query: Ehime University, Ehime University, 2-5 Bunkyo-cho
# INFO:root:✅ Match found with candidate 1: Ehime University
# INFO:root:🔍 Query: INAF - Osservatorio Astronomico di Roma, via di Frascati 33, 00078 Monte Porzio Catone
# INFO:root:❌ No match for candidate 1: Astronomical Observatory of Rome
# INFO:root:❌ No match for candidate 2: Osservatorio Astronomico di Monte Agliale
# INFO:root:❌ No match for candidate 3: Brera Astronomical Observatory
# INFO:root:⚠️ No match found, fallback to first candidate: Astronomical Observatory of Rome
# INFO:root:🔍 Query: Cahill Center for Astronomy and Astrophysics, California Institute of Technology, Pasadena
# INFO:root:❌ No match for candidate 1: Institute of Astronomy and Astrophysics, Academia Sinica
# INFO:root:❌ No match for candidate 2: Research Institute for Astronomy and Astrophysics of Maragh
# INFO:root:❌ No match for candidate 3: Inter-University Centre for Astronomy and Astrophysics
# INFO:root:⚠️ No match found, fallback to first candidate: Institute of Astronomy and Astrophysics, Academia Sinica
# INFO:root:🔍 Query: Jet Propulsion Laboratory, California Institute of Technology, 4800 Oak Grove Drive
# INFO:root:✅ Match found with candidate 1: Jet Propulsion Laboratory
# INFO:root:🔍 Query:  PO Box 208120
# INFO:root:❌ No match for candidate 1: Box Hill Hospital
# INFO:root:❌ No match for candidate 2: Electrik Box (Canada)
# INFO:root:❌ No match for candidate 3: Box (United States)
# INFO:root:⚠️ No match found, fallback to first candidate: Box Hill Hospital
# INFO:root:🔍 Query: Purdue University
# INFO:root:❌ No match for candidate 1: Purdue University Northwest
# INFO:root:❌ No match for candidate 2: Purdue University System
# INFO:root:❌ No match for candidate 3: Purdue University Fort Wayne
# INFO:root:⚠️ No match found, fallback to first candidate: Purdue University Northwest
# INFO:root:🔍 Query: Leiden University, Leiden University, PO Box 9513
# INFO:root:✅ Match found with candidate 1: Leiden University
# INFO:root:🔍 Query: University of Edinburgh, University of Edinburgh, Royal Observatory
# INFO:root:✅ Match found with candidate 1: University of Edinburgh
# ERROR:root:ROR API query failed with status code: 500 for institution: SURF/SURFsara, Science Park 140, 1098 XG Amsterdam
# INFO:root:🔍 Query: The Open University, The Open University, Walton Hall
# INFO:root:✅ Match found with candidate 1: The Open University
# INFO:root:🔍 Query: ASTRON, The Netherlands Institute for Radio Astronomy, Postbus 2
# INFO:root:✅ Match found with candidate 1: Netherlands Institute for Radio Astronomy
# INFO:root:🔍 Query: ETH Zurich, Institute for Particle Physics and Astrophysics, Wolfgang-Pauli-Str 27
# INFO:root:❌ No match for candidate 1: Wolfgang Pauli Institute
# INFO:root:✅ Match found with candidate 2: Institute for Particle Physics and Astrophysics
# INFO:root:🔍 Query: INAF-IAPS, Via Fosso del Cavaliere 100, 00133
# INFO:root:❌ No match for candidate 1: Institute for Space Astrophysics and Planetology
# INFO:root:❌ No match for candidate 2: Jeunesse - Activité Physique et Sportive, santé
# INFO:root:❌ No match for candidate 3: National Institute for Astrophysics
# INFO:root:⚠️ No match found, fallback to first candidate: Institute for Space Astrophysics and Planetology
# INFO:root:🔍 Query: Durham University, Durham University, Durham DH1 3LE
# INFO:root:✅ Match found with candidate 1: Durham University
# INFO:root:🔍 Query: University of Durham, University of Durham, South Road
# INFO:root:❌ No match for candidate 1: Durham University
# INFO:root:❌ No match for candidate 2: University Hospital of North Durham
# INFO:root:❌ No match for candidate 3: Teikyo University of Japan in Durham
# INFO:root:⚠️ No match found, fallback to first candidate: Durham University
# WARNING:root:No ROR information found for 'WeBank'.
# INFO:root:🔍 Query: WeBank and Hong Kong University of Science and Technology
# INFO:root:✅ Match found with candidate 1: Hong Kong University of Science and Technology
# INFO:root:🔍 Query:  addressline=Indian Institute of Technology Guwahati, city=Guwahati
# INFO:root:✅ Match found with candidate 1: Indian Institute of Technology Guwahati
# INFO:root:🔍 Query: Illinois Institute of Technology
# INFO:root:✅ Match found with candidate 1: Illinois Institute of Technology
# INFO:root:🔍 Query: University of Illinois Chicago
# INFO:root:✅ Match found with candidate 1: University of Illinois Chicago
# INFO:root:🔍 Query: Cisco Research
# INFO:root:❌ No match for candidate 1: Cisco And Cisco Productions
# INFO:root:❌ No match for candidate 2: Cisco College
# INFO:root:❌ No match for candidate 3: Cisco Systems (Netherlands)
# INFO:root:⚠️ No match found, fallback to first candidate: Cisco And Cisco Productions
# INFO:root:🔍 Query: IBC
# INFO:root:❌ No match for candidate 1: IBC Advanced Technologies (United States)
# INFO:root:❌ No match for candidate 2: Institute for Behavior Change
# INFO:root:❌ No match for candidate 3: Institute of Biological Chemistry, Academia Sinica
# INFO:root:⚠️ No match found, fallback to first candidate: IBC Advanced Technologies (United States)
# INFO:root:🔍 Query: UERJ
# INFO:root:❌ No match for candidate 1: Universidade do Estado do Rio de Janeiro
# INFO:root:❌ No match for candidate 2: Instituto Politécnico do Rio de Janeiro
# INFO:root:⚠️ No match found, fallback to first candidate: Universidade do Estado do Rio de Janeiro
# INFO:root:🔍 Query: PUC-RIO
# INFO:root:❌ No match for candidate 1: Pontifical Catholic University of Rio de Janeiro
# INFO:root:❌ No match for candidate 2: Pacific Union College
# INFO:root:❌ No match for candidate 3: California Public Utilities Commission
# INFO:root:⚠️ No match found, fallback to first candidate: Pontifical Catholic University of Rio de Janeiro
# INFO:root:🔍 Query: Dalhousie University, Dalhousie University, Halifax
# INFO:root:✅ Match found with candidate 1: Dalhousie University
# INFO:root:🔍 Query: Stony Brook University, Stony Brook University, Stony Brook
# INFO:root:✅ Match found with candidate 1: Stony Brook University
# INFO:root:🔍 Query: Mathematics Area, MathLab, International School for Advanced Studies (SISSA)
# INFO:root:❌ No match for candidate 1: Scuola Internazionale Superiore di Studi Avanzati
# INFO:root:❌ No match for candidate 2: Johns Hopkins University School of Advanced International Studies
# INFO:root:❌ No match for candidate 3: International Center for Advanced Studies
# INFO:root:⚠️ No match found, fallback to first candidate: Scuola Internazionale Superiore di Studi Avanzati
# INFO:root:🔍 Query:  Eindhoven University of Technology, Netherlands.
# INFO:root:✅ Match found with candidate 1: Eindhoven University of Technology
# INFO:root:🔍 Query: The Hong Kong University of Science and Technology, The Hong Kong University of Science and Technology, Hong Kong
# INFO:root:✅ Match found with candidate 1: Hong Kong University of Science and Technology
# INFO:root:🔍 Query: University of Urbino Carlo Bo, University of Urbino Carlo Bo, Urbino
# INFO:root:✅ Match found with candidate 1: University of Urbino
# INFO:root:🔍 Query:  Pisa
# INFO:root:❌ No match for candidate 1: Fondazione Pisa
# INFO:root:❌ No match for candidate 2: Istituto Nazionale di Fisica Nucleare, Sezione di Pisa
# INFO:root:❌ No match for candidate 3: University of Pisa
# INFO:root:⚠️ No match found, fallback to first candidate: Fondazione Pisa
# INFO:root:🔍 Query: Deusto University, Deusto University, Bilbao
# INFO:root:❌ No match for candidate 1: Universidad de Deusto
# INFO:root:❌ No match for candidate 2: Metro Bilbao
# INFO:root:❌ No match for candidate 3: Ayuntamiento de Bilbao
# INFO:root:⚠️ No match found, fallback to first candidate: Universidad de Deusto
# WARNING:root:No ROR information found for 'Alipay, AntGroup'.
# INFO:root:🔍 Query: Imperial College London
# INFO:root:✅ Match found with candidate 1: Imperial College London
# INFO:root:🔍 Query: Institut für Physik, Johannes Gutenberg-Universität Mainz, 55099 Mainz
# INFO:root:❌ No match for candidate 1: Johannes Gutenberg University Mainz
# INFO:root:❌ No match for candidate 2: University Medical Center of the Johannes Gutenberg University Mainz
# INFO:root:❌ No match for candidate 3: Translationale Onkologie an der Universitätsmedizin der Johannes Gutenberg-Universität Mainz
# INFO:root:⚠️ No match found, fallback to first candidate: Johannes Gutenberg University Mainz
# INFO:root:🔍 Query: ICFO—Institut de Ciències Fotòniques, The Barcelona Institute of Science and Technology, 08860 Castelldefels
# INFO:root:❌ No match for candidate 1: Institute of Photonic Sciences
# INFO:root:❌ No match for candidate 2: Museu de Ciències Naturals de Barcelona
# INFO:root:❌ No match for candidate 3: Institute of Space Sciences
# INFO:root:⚠️ No match found, fallback to first candidate: Institute of Photonic Sciences
# INFO:root:🔍 Query: ICREA—Institució Catalana de Recerca i Estudis Avançats, 08015 Barcelona, Spain
# INFO:root:✅ Match found with candidate 1: Institució Catalana de Recerca i Estudis Avançats
# INFO:root:🔍 Query: Beihang University
# INFO:root:✅ Match found with candidate 1: Beihang University
# INFO:root:🔍 Query: The Australian National University
# INFO:root:✅ Match found with candidate 1: Australian National University
# INFO:root:🔍 Query: Washington State University, Pullman
# INFO:root:✅ Match found with candidate 1: Washington State University
# INFO:root:🔍 Query: East China Normal University
# INFO:root:✅ Match found with candidate 1: East China Normal University
# INFO:root:🔍 Query: The Hong Kong Polytechnic University
# INFO:root:✅ Match found with candidate 1: Hong Kong Polytechnic University
# INFO:root:🔍 Query: University of Luxembourg
# INFO:root:✅ Match found with candidate 1: University of Luxembourg
# INFO:root:🔍 Query: National University of Defense Technology
# INFO:root:✅ Match found with candidate 1: National University of Defense Technology
# INFO:root:🔍 Query: Indian Institute of Information Technology Sri City, Chittoor
# INFO:root:✅ Match found with candidate 1: Indian Institute of Information Technology Sri City
# INFO:root:🔍 Query: Wayne State University
# INFO:root:✅ Match found with candidate 1: Wayne State University
# INFO:root:🔍 Query: Georgia State University
# INFO:root:✅ Match found with candidate 1: Georgia State University
# INFO:root:🔍 Query: Departamento de Física, Universidade Federal da Paraíba, Caixa Postal 5008
# INFO:root:✅ Match found with candidate 1: Universidade Federal da Paraíba
# INFO:root:🔍 Query: Institut für Astronomie und Astrophysik, Universität Tübingen, Sand 1
# INFO:root:❌ No match for candidate 1: Zentrum für Datenverarbeitung
# INFO:root:❌ No match for candidate 2: Institute for Particle Physics and Astrophysics
# INFO:root:❌ No match for candidate 3: University of Tübingen
# INFO:root:⚠️ No match found, fallback to first candidate: Zentrum für Datenverarbeitung
# INFO:root:🔍 Query: IRFU, CEA, Département de Physique des Particules
# INFO:root:❌ No match for candidate 1: Laboratoire d’Annecy de Physique des Particules
# INFO:root:❌ No match for candidate 2: Centre de physique des particules de Marseille
# INFO:root:❌ No match for candidate 3: Institut National de Physique Nucléaire et de Physique des Particules
# INFO:root:⚠️ No match found, fallback to first candidate: Laboratoire d’Annecy de Physique des Particules
# INFO:root:🔍 Query: Tel Aviv University, Tel Aviv University, Tel Aviv 6997801
# INFO:root:✅ Match found with candidate 1: Tel Aviv University
# INFO:root:🔍 Query:  NRCN, P.O. Box 9001
# INFO:root:❌ No match for candidate 1: Shimon Peres Negev Nuclear Research Center
# INFO:root:❌ No match for candidate 2: P. O. Zetterlings stiftelse
# INFO:root:❌ No match for candidate 3: Box Hill Hospital
# INFO:root:⚠️ No match found, fallback to first candidate: Shimon Peres Negev Nuclear Research Center
# INFO:root:🔍 Query: Ben-Gurion University of the Negev, Ben-Gurion University of the Negev, Beer-Sheva 84105
# INFO:root:✅ Match found with candidate 1: Ben-Gurion University of the Negev
# INFO:root:🔍 Query: University of Michigan, University of Michigan, Ann Arbor
# INFO:root:✅ Match found with candidate 1: University of Michigan
# INFO:root:🔍 Query: Cornell Tech
# INFO:root:❌ No match for candidate 1: Cornell University Agricultural Experiment Station
# INFO:root:❌ No match for candidate 2: Cornell College
# INFO:root:❌ No match for candidate 3: Cornell University
# INFO:root:⚠️ No match found, fallback to first candidate: Cornell University Agricultural Experiment Station
# INFO:root:🔍 Query: Rutgers University
# INFO:root:❌ No match for candidate 1: Rutgers, The State University of New Jersey
# INFO:root:❌ No match for candidate 2: Rutgers Sexual and Reproductive Health and Rights
# INFO:root:❌ No match for candidate 3: Rutgers Health
# INFO:root:⚠️ No match found, fallback to first candidate: Rutgers, The State University of New Jersey
# INFO:root:🔍 Query: University of Edinburgh
# INFO:root:✅ Match found with candidate 1: University of Edinburgh
# INFO:root:🔍 Query: Cornell University
# INFO:root:✅ Match found with candidate 1: Cornell University
# INFO:root:🔍 Query: Pennsylvania State University, Pennsylvania State University, State College
# INFO:root:✅ Match found with candidate 1: Pennsylvania State University
# INFO:root:🔍 Query: Peking University, Peking University, Beijing
# INFO:root:✅ Match found with candidate 1: Peking University
# INFO:root:🔍 Query: Wright State University, Wright State University, Dayton
# INFO:root:✅ Match found with candidate 1: Wright State University
# INFO:root:🔍 Query: Agency for Science, Technology, and Research (A*STAR)
# INFO:root:❌ No match for candidate 1: Agency for Science, Technology and Research
# INFO:root:❌ No match for candidate 2: Agency for Science, Innovation and Technology
# INFO:root:❌ No match for candidate 3: Japan Science and Technology Agency
# INFO:root:⚠️ No match found, fallback to first candidate: Agency for Science, Technology and Research
# INFO:root:🔍 Query: Southern University of Science and Technology (SUSTech)
# INFO:root:✅ Match found with candidate 1: Southern University of Science and Technology
# INFO:root:🔍 Query: University of Technology Sydney (UTS)
# INFO:root:✅ Match found with candidate 1: University of Technology Sydney
# INFO:root:🔍 Query: The Ohio State University, The Ohio State University, 231 W. 18th Avenue
# INFO:root:✅ Match found with candidate 1: The Ohio State University
# INFO:root:🔍 Query: Paolo Piccione Departamento de Matemática, Instituto de Matemática e Estatística, Universidade de São Paulo
# INFO:root:❌ No match for candidate 1: Centro de Matemática
# INFO:root:❌ No match for candidate 2: Instituto de Matemática de Bahía Blanca
# INFO:root:❌ No match for candidate 3: Instituto tecnológico de Matemática Industrial
# INFO:root:⚠️ No match found, fallback to first candidate: Centro de Matemática
# INFO:root:🔍 Query:  Technion, Haifa
# INFO:root:❌ No match for candidate 1: Technion – Israel Institute of Technology
# INFO:root:❌ No match for candidate 2: Guangdong Technion-Israel Institute of Technology
# INFO:root:❌ No match for candidate 3: IBM Research - Haifa
# INFO:root:⚠️ No match found, fallback to first candidate: Technion – Israel Institute of Technology
# INFO:root:🔍 Query: Université Paris Dauphine - PSL
# INFO:root:❌ No match for candidate 1: Université Paris Dauphine-PSL
# INFO:root:❌ No match for candidate 2: École Nationale Supérieure des Mines de Paris
# INFO:root:❌ No match for candidate 3: Université Paris Sciences et Lettres
# INFO:root:⚠️ No match found, fallback to first candidate: Université Paris Dauphine-PSL
# INFO:root:🔍 Query: Quandela, 7 Rue Léonard de Vinci, 91300 Massy
# INFO:root:❌ No match for candidate 1: Pôle Universitaire Léonard de Vinci
# INFO:root:❌ No match for candidate 2: Haute École Léonard de Vinci
# INFO:root:❌ No match for candidate 3: Ecole Supérieure d'Ingénieurs Léonard de Vinci
# INFO:root:⚠️ No match found, fallback to first candidate: Pôle Universitaire Léonard de Vinci
# INFO:root:🔍 Query: Sorbonne Université, CNRS, LIP6
# INFO:root:✅ Match found with candidate 1: Sorbonne Université
# INFO:root:🔍 Query: University of Birmingham, University of Birmingham, addressline=Edgbaston
# INFO:root:✅ Match found with candidate 1: University of Birmingham
# INFO:root:🔍 Query: organization=Diamond Light Source Ltd., addressline=Harwell Science and Innovation Campus, city=Didcot
# INFO:root:✅ Match found with candidate 1: Diamond Light Source
# INFO:root:🔍 Query: University of Warwick, University of Warwick, city=Coventry
# INFO:root:✅ Match found with candidate 1: University of Warwick
# INFO:root:🔍 Query: organization=METAL group, INSA Lyon, addressline=25 Avenue Jean Capelle
# INFO:root:❌ No match for candidate 1: Institut National des Sciences Appliquées de Lyon
# INFO:root:❌ No match for candidate 2: Matthew 25
# INFO:root:❌ No match for candidate 3: Université Jean Moulin Lyon III
# INFO:root:⚠️ No match found, fallback to first candidate: Institut National des Sciences Appliquées de Lyon
# INFO:root:🔍 Query: organization=European Synchrotron Radiation Facility (ESRF), addressline=71 Avenue des Martyrs, city=38000 Grenoble
# INFO:root:✅ Match found with candidate 1: European Synchrotron Radiation Facility
# INFO:root:🔍 Query: University of Cincinnati, University of Cincinnati, Cincinnati
# INFO:root:✅ Match found with candidate 1: University of Cincinnati
# INFO:root:🔍 Query: Umm Al-Qura University, Umm Al-Qura University, Mecca
# INFO:root:✅ Match found with candidate 1: Umm al-Qura University
# INFO:root:🔍 Query: AGH University of Krakow, AGH University of Krakow, Faculty of Physics and Applied Computer Science
# INFO:root:✅ Match found with candidate 1: AGH University of Krakow
# INFO:root:🔍 Query: University of Mississippi, University of Mississippi, University
# INFO:root:✅ Match found with candidate 1: University of Mississippi
# INFO:root:🔍 Query: University of Texas, University of Texas, Austin
# INFO:root:❌ No match for candidate 1: The University of Texas at Austin
# INFO:root:❌ No match for candidate 2: University of North Texas
# INFO:root:❌ No match for candidate 3: Texas A&M University – Central Texas
# INFO:root:⚠️ No match found, fallback to first candidate: The University of Texas at Austin
# ERROR:root:ROR API query failed with status code: 500 for institution: bInstituto de Física Teórica UAM/CSIC, Calle Nicolas Cabrera 13-15, Madrid 28049
# INFO:root:🔍 Query:  Pisa 56127, Italy
#  robertlpoe@icloud.com
# INFO:root:❌ No match for candidate 1: Fondazione Pisa
# INFO:root:❌ No match for candidate 2: Istituto Nazionale di Fisica Nucleare, Sezione di Pisa
# INFO:root:❌ No match for candidate 3: University of Pisa
# INFO:root:⚠️ No match found, fallback to first candidate: Fondazione Pisa
# INFO:root:🔍 Query: Cornell University, Cornell University, Ithaca
# INFO:root:✅ Match found with candidate 1: Cornell University
# INFO:root:🔍 Query: University of North Texas, University of North Texas, Denton
# INFO:root:✅ Match found with candidate 1: University of North Texas
# INFO:root:🔍 Query:  Changshu Institute of Technology, Changshu 215500
# INFO:root:✅ Match found with candidate 1: Changshu Institute of Technology
# INFO:root:🔍 Query: Nanjing University of Posts and Telecommunications, Nanjing University of Posts and Telecommunications, Nanjing 210023
# INFO:root:✅ Match found with candidate 1: Nanjing University of Posts and Telecommunications
# INFO:root:🔍 Query: Hunan Normal University, Hunan Normal University, Changsha 410081
# INFO:root:✅ Match found with candidate 1: Hunan Normal University
# INFO:root:🔍 Query: Center for High Pressure Science and Technology Advanced Research, Shanghai 201203, China
# INFO:root:❌ No match for candidate 1: Center for High Pressure Science & Technology Advanced Research
# INFO:root:❌ No match for candidate 2: Center for High Pressure Science & Technology Advanced Research
# INFO:root:✅ Match found with candidate 3: Center for High Pressure Science and Technology Advanced Research
# INFO:root:🔍 Query: Ningbo University, Ningbo University, Ningbo 315211
# INFO:root:✅ Match found with candidate 1: Ningbo University
# INFO:root:🔍 Query: Zhejiang University of Technology, Zhejiang University of Technology, Hangzhou 310023
# INFO:root:✅ Match found with candidate 1: Zhejiang University of Technology
# INFO:root:🔍 Query: Sharif University of Technology, Sharif University of Technology, Tehran 11155-9161
# INFO:root:✅ Match found with candidate 1: Sharif University of Technology
# INFO:root:🔍 Query:  Institute for Research in Fundamental Sciences (IPM), Tehran 19395-5531
# INFO:root:✅ Match found with candidate 1: Institute for Research in Fundamental Sciences
# INFO:root:🔍 Query: University of Missouri, University of Missouri, Columbia
# INFO:root:✅ Match found with candidate 1: University of Missouri
# INFO:root:🔍 Query: 1
# INFO:root:❌ No match for candidate 1: Maine School Administrative District 1
# INFO:root:❌ No match for candidate 2: Instituto Hispalense de Pediatria
# INFO:root:❌ No match for candidate 3: Riddargatan 1
# INFO:root:⚠️ No match found, fallback to first candidate: Maine School Administrative District 1
# INFO:root:🔍 Query: 2
# INFO:root:❌ No match for candidate 1: Recycled Materials Resource Center
# INFO:root:❌ No match for candidate 2: 2-Spirited
# INFO:root:❌ No match for candidate 3: Space Delta 2
# INFO:root:⚠️ No match found, fallback to first candidate: Recycled Materials Resource Center
# INFO:root:🔍 Query: 3
# INFO:root:❌ No match for candidate 1: Inter 3
# INFO:root:❌ No match for candidate 2: Institut des Sciences du Calcul et des Données
# INFO:root:❌ No match for candidate 3: New York/New Jersey VA Health Care Network
# INFO:root:⚠️ No match found, fallback to first candidate: Inter 3
# INFO:root:🔍 Query: 4
# INFO:root:❌ No match for candidate 1: VA Healthcare-VISN 4
# INFO:root:❌ No match for candidate 2: Space Delta 4
# INFO:root:❌ No match for candidate 3: H2O 4 All
# INFO:root:⚠️ No match found, fallback to first candidate: VA Healthcare-VISN 4
# INFO:root:🔍 Query: University of California, University of California, Berkeley
# INFO:root:✅ Match found with candidate 1: University of California, Berkeley
# INFO:root:🔍 Query: Theory Group, Lawrence Berkeley National Laboratory, Berkeley
# INFO:root:✅ Match found with candidate 1: Lawrence Berkeley National Laboratory
# INFO:root:🔍 Query: INFN, Sezione di Firenze Via G. Sansone 1, 50019 Sesto Fiorentino
# INFO:root:❌ No match for candidate 1: Istituto Nazionale di Fisica Nucleare, Sezione di Firenze
# INFO:root:❌ No match for candidate 2: Istituto Nazionale di Fisica Nucleare, Sezione di Roma I
# INFO:root:❌ No match for candidate 3: Istituto Nazionale di Fisica Nucleare, Sezione di Milano Bicocca
# INFO:root:⚠️ No match found, fallback to first candidate: Istituto Nazionale di Fisica Nucleare, Sezione di Firenze
# INFO:root:🔍 Query: Universitat Politècnica de Catalunya
# INFO:root:✅ Match found with candidate 1: Universitat Politècnica de Catalunya
# INFO:root:🔍 Query: University of Cyprus
# INFO:root:✅ Match found with candidate 1: University of Cyprus
# INFO:root:🔍 Query: CYENS Centre of Excellence
# INFO:root:❌ No match for candidate 1: Textile Centre of Excellence
# INFO:root:❌ No match for candidate 2: Centre of Excellence NAMASTE
# INFO:root:❌ No match for candidate 3: GNSS Centre of Excellence
# INFO:root:⚠️ No match found, fallback to first candidate: Textile Centre of Excellence
# INFO:root:🔍 Query: INFN, Sezione di Roma, I-00185 Roma
# INFO:root:❌ No match for candidate 1: Istituto Nazionale di Fisica Nucleare, Sezione di Roma I
# INFO:root:❌ No match for candidate 2: Istituto Nazionale di Fisica Nucleare, Sezione di Roma Tre
# INFO:root:❌ No match for candidate 3: Istituto Nazionale di Fisica Nucleare, Roma Tor Vergata
# INFO:root:⚠️ No match found, fallback to first candidate: Istituto Nazionale di Fisica Nucleare, Sezione di Roma I
# INFO:root:🔍 Query: Università di Napoli “Federico II”, I-80126 Napoli, Italy
# INFO:root:❌ No match for candidate 1: University of Naples Federico II
# INFO:root:❌ No match for candidate 2: Parthenope University of Naples
# INFO:root:❌ No match for candidate 3: University of Naples - L'Orientale
# INFO:root:⚠️ No match found, fallback to first candidate: University of Naples Federico II
# INFO:root:🔍 Query: INFN, Sezione di Napoli, I-80126 Napoli
# INFO:root:❌ No match for candidate 1: Istituto Nazionale di Fisica Nucleare, Sezione di Napoli
# INFO:root:❌ No match for candidate 2: Istituto Nazionale di Fisica Nucleare, Gruppo Collegato di Salerno
# INFO:root:❌ No match for candidate 3: Federico II University Hospital
# INFO:root:⚠️ No match found, fallback to first candidate: Istituto Nazionale di Fisica Nucleare, Sezione di Napoli
# INFO:root:🔍 Query: Università di Roma "Sapienza", I-00185 Roma, Italy
# INFO:root:❌ No match for candidate 1: Sapienza University of Rome
# INFO:root:❌ No match for candidate 2: Università degli Studi Internazionali di Roma
# INFO:root:❌ No match for candidate 3: University of Rome Tor Vergata
# INFO:root:⚠️ No match found, fallback to first candidate: Sapienza University of Rome
# INFO:root:🔍 Query: Institut de Fisica d’Altes Energies (IFAE), The Barcelona Institute of Science and Technology, Campus UAB
# INFO:root:❌ No match for candidate 1: Institute for High Energy Physics
# INFO:root:❌ No match for candidate 2: Barcelona Institute for Science and Technology
# INFO:root:❌ No match for candidate 3: Birla Institute of Technology and Science - Hyderabad Campus
# INFO:root:⚠️ No match found, fallback to first candidate: Institute for High Energy Physics
# INFO:root:🔍 Query: University of Tasmania
# INFO:root:✅ Match found with candidate 1: University of Tasmania
# INFO:root:🔍 Query: University of Hull, University of Hull, Cottingham Road
# INFO:root:✅ Match found with candidate 1: University of Hull
# INFO:root:🔍 Query: International Centre for Radio Astronomy Research (ICRAR), Curtin University, Bentley WA 6102 Australia
# INFO:root:✅ Match found with candidate 1: International Centre for Radio Astronomy Research
# ERROR:root:ROR API query failed with status code: 500 for institution: Laboratoire de Physique et Chimie de l’Environnement et de l’Espace, Université d’Orléans/CNRS, F-45071 Orléans Cedex 02
# INFO:root:🔍 Query: Observatoire Radioastronomique de Nançay, Observatoire de Paris, Université PSL
# INFO:root:✅ Match found with candidate 1: Observatoire Radioastronomique de Nançay
# INFO:root:🔍 Query: PSL Research University, PSL Research University, Meudon
# INFO:root:❌ No match for candidate 1: Université Paris Sciences et Lettres
# INFO:root:❌ No match for candidate 2: Process Simulations Limited (Canada)
# INFO:root:❌ No match for candidate 3: Thyssenkrupp (Slovakia)
# INFO:root:⚠️ No match found, fallback to first candidate: Université Paris Sciences et Lettres
# INFO:root:🔍 Query: The University of Manchester, The University of Manchester, Manchester M13 9PL
# INFO:root:✅ Match found with candidate 1: University of Manchester
# INFO:root:🔍 Query: OzGrav-Swinburne University of Technology, VIC 3166, Australia
# INFO:root:✅ Match found with candidate 1: Swinburne University of Technology
# INFO:root:🔍 Query: Ben-Gurion University of the Negev, Ben-Gurion University of the Negev, Sede Boqer Campus
# INFO:root:✅ Match found with candidate 1: Ben-Gurion University of the Negev
# INFO:root:🔍 Query: University of Basel, University of Basel, Klingelbergstrasse 82
# INFO:root:✅ Match found with candidate 1: University of Basel
# INFO:root:🔍 Query:  King’s College London, Strand
# INFO:root:❌ No match for candidate 1: King's College London
# INFO:root:❌ No match for candidate 2: Bansomdejchaopraya Rajabhat University
# INFO:root:❌ No match for candidate 3: King’s University College
# INFO:root:⚠️ No match found, fallback to first candidate: King's College London
# INFO:root:🔍 Query: University of Bern, University of Bern, CH-3012 Bern
# INFO:root:✅ Match found with candidate 1: University of Bern
# INFO:root:🔍 Query: Meta AI
# INFO:root:❌ No match for candidate 1: META Group
# INFO:root:❌ No match for candidate 2: META Health
# INFO:root:❌ No match for candidate 3: Meta House
# INFO:root:⚠️ No match found, fallback to first candidate: META Group
# INFO:root:🔍 Query: Tampere University
# INFO:root:✅ Match found with candidate 1: Tampere University
# INFO:root:🔍 Query: Instituto de Física Teórica UAM-CSIC and Departamento de Física Teórica, Universidad Autónoma de Madrid, Cantoblanco
# INFO:root:✅ Match found with candidate 1: Instituto de Física Teórica
# WARNING:root:No ROR information found for ' 1211 Meyrin'.
# INFO:root:🔍 Query: Università di Torino, Dipartimento di Fisica and INFN, Sezione di Torino
# INFO:root:❌ No match for candidate 1: Istituto Nazionale di Fisica Nucleare, Sezione di Torino
# INFO:root:❌ No match for candidate 2: University of Turin
# INFO:root:❌ No match for candidate 3: Polytechnic University of Turin
# INFO:root:⚠️ No match found, fallback to first candidate: Istituto Nazionale di Fisica Nucleare, Sezione di Torino
# INFO:root:🔍 Query: Dipartimento SMFI, Università di Parma and INFN, Gruppo Collegato di Parma
# INFO:root:❌ No match for candidate 1: Istituto Nazionale di Fisica Nucleare, Gruppo Collegato di Parma
# INFO:root:❌ No match for candidate 2: University of Parma
# INFO:root:❌ No match for candidate 3: Ospedale di Parma
# INFO:root:⚠️ No match found, fallback to first candidate: Istituto Nazionale di Fisica Nucleare, Gruppo Collegato di Parma
# INFO:root:🔍 Query: Google Research Tel Aviv
# INFO:root:❌ No match for candidate 1: Tel Aviv University
# INFO:root:❌ No match for candidate 2: Tel Aviv Sourasky Medical Center
# INFO:root:❌ No match for candidate 3: Academic College of Tel Aviv-Yafo
# INFO:root:⚠️ No match found, fallback to first candidate: Tel Aviv University
# INFO:root:🔍 Query: Weizmann Institute of Science
# INFO:root:✅ Match found with candidate 1: Weizmann Institute of Science
# INFO:root:🔍 Query:  Tel Aviv University
# INFO:root:✅ Match found with candidate 1: Tel Aviv University
# INFO:root:🔍 Query:  Indian Institute of Technology Bombay, Powai
# INFO:root:✅ Match found with candidate 1: Indian Institute of Technology Bombay
# INFO:root:🔍 Query:  Tata Institute of Fundamental Research, Colaba
# INFO:root:✅ Match found with candidate 1: Tata Institute of Fundamental Research
# INFO:root:🔍 Query: Kyoto University, Kyoto University, Sakyo-ku
# INFO:root:✅ Match found with candidate 1: Kyoto University
# INFO:root:🔍 Query: eBay Inc.
# INFO:root:❌ No match for candidate 1: eBay (Ireland)
# INFO:root:❌ No match for candidate 2: eBay (South Korea)
# INFO:root:❌ No match for candidate 3: eBay (United States)
# INFO:root:⚠️ No match found, fallback to first candidate: eBay (Ireland)
# INFO:root:🔍 Query: Vienna University of Technology, Vienna University of Technology, 1040 Vienna
# INFO:root:❌ No match for candidate 1: TU Wien
# INFO:root:❌ No match for candidate 2: University of Vienna
# INFO:root:❌ No match for candidate 3: Pädagogische Hochschule Wien
# INFO:root:⚠️ No match found, fallback to first candidate: TU Wien
# INFO:root:🔍 Query: University of Vienna, University of Vienna, 1090 Vienna
# INFO:root:✅ Match found with candidate 1: University of Vienna
# INFO:root:🔍 Query: Max Planck Institute for Chemical Physics of Solids, 01187 Dresden, Germany
# INFO:root:✅ Match found with candidate 1: Max Planck Institute for Chemical Physics of Solids
# INFO:root:🔍 Query: Goethe University Frankfurt, Goethe University Frankfurt, 60438 Frankfurt a.M.
# INFO:root:✅ Match found with candidate 1: Goethe University Frankfurt
# ERROR:root:ROR API query failed with status code: 500 for institution: Donostia International Physics Center, 20018 Donostia/San Sebastián, Spain
# INFO:root:🔍 Query: Charles University, Charles University, 121 16 Prague
# INFO:root:✅ Match found with candidate 1: Charles University
# INFO:root:🔍 Query: Perimeter Institute for Theoretical Physics, 31 Caroline St. N., Waterloo ON
# INFO:root:✅ Match found with candidate 1: Perimeter Institute
# ERROR:root:ROR API query failed with status code: 500 for institution: Institute for Theoretical Physics, TU Wien, Wiedner Hauptstrasse 8–10/136
# INFO:root:🔍 Query: Center for Functional Nanomaterials, Brookhaven National Laboratory, Upton
# INFO:root:✅ Match found with candidate 1: Center for Functional Nanomaterials
# INFO:root:🔍 Query: Harvard University, Harvard University, Cambridge
# INFO:root:✅ Match found with candidate 1: Harvard University
# INFO:root:🔍 Query: Northwestern University, Northwestern University, 1800 Sherman Ave
# INFO:root:✅ Match found with candidate 1: Northwestern University
# INFO:root:🔍 Query:  370 Lancaster Ave, Haverford
# INFO:root:❌ No match for candidate 1: Haverford College
# INFO:root:❌ No match for candidate 2: Atlas of Variant Effects Alliance
# INFO:root:❌ No match for candidate 3: AVE (Czechia)
# INFO:root:⚠️ No match found, fallback to first candidate: Haverford College
# INFO:root:🔍 Query: Northwestern University, Northwestern University, 2145 Sheridan Road
# INFO:root:✅ Match found with candidate 1: Northwestern University
# INFO:root:🔍 Query:  Illinois Institute of Technology, Chicago
# INFO:root:❌ No match for candidate 1: University of Illinois Chicago
# INFO:root:✅ Match found with candidate 2: Illinois Institute of Technology
# INFO:root:🔍 Query: University of Utah, University of Utah, Salt Lake City
# INFO:root:✅ Match found with candidate 1: University of Utah
# INFO:root:🔍 Query: University of Massachusetts Amherst, University of Massachusetts Amherst, Amherst
# INFO:root:✅ Match found with candidate 1: University of Massachusetts Amherst
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): Unexpected mismatching closing brace: '}' @(15774,0)
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): Unexpected mismatching closing brace: '}' @(16457,0)
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): Unexpected mismatching closing brace: '}' @(16661,0)
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): Unexpected mismatching closing brace: '}' @(40462,0)
# INFO:root:🔍 Query:  The College of New Jersey, Ewing
# INFO:root:✅ Match found with candidate 1: College of New Jersey
# INFO:root:🔍 Query: Xinzhou Normal University, Xinzhou Normal University, Xinzhou 034000
# INFO:root:❌ No match for candidate 1: Xinzhou Teachers University
# INFO:root:❌ No match for candidate 2: Henan Normal University
# INFO:root:❌ No match for candidate 3: Gannan Normal University
# INFO:root:⚠️ No match found, fallback to first candidate: Xinzhou Teachers University
# INFO:root:🔍 Query: Shanxi University, Shanxi University, Taiyuan 030006
# INFO:root:✅ Match found with candidate 1: Shanxi University
# INFO:root:🔍 Query: Laboratory of High Energy Physics, Physical-Technical Institute of Uzbekistan Academy of Sciences, Chingiz Aytmatov Str. 2b
# INFO:root:❌ No match for candidate 1: Institute of High Energy Physics
# INFO:root:❌ No match for candidate 2: Institute of High Energy Physics
# INFO:root:❌ No match for candidate 3: Academy of Sciences Republic of Uzbekistan
# INFO:root:⚠️ No match found, fallback to first candidate: Institute of High Energy Physics
# INFO:root:🔍 Query: National University of Science and Technology MISIS (NUST MISIS), National University of Science and Technology MISIS (NUST MISIS), Almalyk Branch
# INFO:root:✅ Match found with candidate 1: National University of Science and Technology
# INFO:root:🔍 Query: Shanghai Institute of Applied Physics, Chinese Academy of Sciences, Shanghai 201800
# INFO:root:✅ Match found with candidate 1: Shanghai Institute of Applied Physics
# INFO:root:🔍 Query: University of Chinese Academy of Sciences, Beijing 100049, China
# INFO:root:❌ No match for candidate 1: China Academy of Chinese Medical Sciences
# ...
# INFO:root:❌ No match for candidate 3: Beijing Academy of Quantum Information Sciences
# INFO:root:⚠️ No match found, fallback to first candidate: Joint Center for Quantum Information and Computer Science
# INFO:root:🔍 Query: Tomsk Polytechnic University, Tomsk Polytechnic University, Lenin Avenue 30
# INFO:root:✅ Match found with candidate 1: Tomsk Polytechnic University
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): Unexpected mismatching closing brace: '}' @(5637,0)
# INFO:root:🔍 Query: Meta Platforms Inc., USA
# INFO:root:❌ No match for candidate 1: Meta (United Kingdom)
# INFO:root:❌ No match for candidate 2: Meta (Israel)
# INFO:root:❌ No match for candidate 3: Meta (United States)
# INFO:root:⚠️ No match found, fallback to first candidate: Meta (United Kingdom)
# INFO:root:🔍 Query: University of Cambridge
# INFO:root:✅ Match found with candidate 1: University of Cambridge
# INFO:root:🔍 Query: Microsoft
# INFO:root:❌ No match for candidate 1: Microsoft (Norway)
# INFO:root:❌ No match for candidate 2: Microsoft (Germany)
# INFO:root:❌ No match for candidate 3: Microsoft (Netherlands)
# INFO:root:⚠️ No match found, fallback to first candidate: Microsoft (Norway)
# INFO:root:🔍 Query: Shanghai Artificial Intelligence Laboratory
# INFO:root:✅ Match found with candidate 1: Shanghai Artificial Intelligence Laboratory
# INFO:root:🔍 Query: University of Chicago, University of Chicago, Chicago
# INFO:root:✅ Match found with candidate 1: University of Chicago
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): End of input while parsing arguments of macro "\" @(1,94)
# Open LaTeX blocks:
#            @(1,94)  arguments of macro "\"
#
# INFO:root:🔍 Query: University of Vienna, University of Vienna, Kolingasse 14-16
# INFO:root:✅ Match found with candidate 1: University of Vienna
# ERROR:root:ROR API query failed with status code: 500 for institution: Vasp Software GmbH, Sensengasse 8/12, 1090
# INFO:root:🔍 Query:  Indian Institute of Science Education and Research Berhampur, Transit Campus
# INFO:root:✅ Match found with candidate 1: Indian Institute of Science Education and Research Berhampur
# INFO:root:🔍 Query: University of Wisconsin-Madison, University of Wisconsin-Madison, 475 N. Charter St.
# INFO:root:❌ No match for candidate 1: University of Wisconsin–Madison
# INFO:root:❌ No match for candidate 2: UW Health University Hospital
# INFO:root:❌ No match for candidate 3: University of Wisconsin Carbone Cancer Center
# INFO:root:⚠️ No match found, fallback to first candidate: University of Wisconsin–Madison
# INFO:root:🔍 Query: University of the West Indies, University of the West Indies, St. Augustine
# INFO:root:✅ Match found with candidate 1: University of the West Indies
# INFO:root:🔍 Query: Thüringer Landessternwarte, Sternwarte 5, D-07778 Tautenburg
# INFO:root:❌ No match for candidate 1: Thüringer Landessternwarte Tautenburg
# INFO:root:❌ No match for candidate 2: Thüringer Aufbaubank
# INFO:root:❌ No match for candidate 3: 5-D Systems (United States)
# INFO:root:⚠️ No match found, fallback to first candidate: Thüringer Landessternwarte Tautenburg
# ERROR:root:ROR API query failed with status code: 500 for institution: Permanent Address: Depto. de Astronomía, Univ. de Guanajuato, Callejón de Jalisco s/n
# INFO:root:🔍 Query:  University of Wisconsin-Madison
# INFO:root:❌ No match for candidate 1: University of Wisconsin–Madison
# INFO:root:❌ No match for candidate 2: UW Health University Hospital
# INFO:root:❌ No match for candidate 3: University of Wisconsin Carbone Cancer Center
# INFO:root:⚠️ No match found, fallback to first candidate: University of Wisconsin–Madison
# INFO:root:🔍 Query: IECL (UMR 7502), Université de Lorraine
# INFO:root:✅ Match found with candidate 1: Université de Lorraine
# INFO:root:🔍 Query: IRMA (UMR 7501), Université de Strasbourg
#  Email:  t  yvain.bruned@univ-lorraine.fr,
#  vdotsenko@unistra.fr.
# INFO:root:✅ Match found with candidate 1: Université de Strasbourg
# INFO:root:🔍 Query: Nicolaus Copernicus Astronomical Centre, Polish Academy of Sciences, ul. Bartycka 18
# INFO:root:❌ No match for candidate 1: Nicolaus Copernicus Astronomical Center
# INFO:root:❌ No match for candidate 2: Astronomical Observatory Nicolaus Copernicus
# INFO:root:❌ No match for candidate 3: Nicolaus Copernicus University
# INFO:root:⚠️ No match found, fallback to first candidate: Nicolaus Copernicus Astronomical Center
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): End of input while parsing arguments of macro "\" @(1,104)
# Open LaTeX blocks:
#           @(1,104)  arguments of macro "\"
#
# INFO:root:🔍 Query: Korea Astronomy and Space Science Institute, 776 Daedeok-daero, Yuseong-gu
# INFO:root:✅ Match found with candidate 1: Korea Astronomy and Space Science Institute
# INFO:root:🔍 Query: National Centre for Nuclear Research, ul. L. Pasteura 7, Warsaw 02-093
# INFO:root:✅ Match found with candidate 1: National Centre for Nuclear Research
# INFO:root:🔍 Query:  Indian Institute of Technology-Bombay, Powai
# INFO:root:❌ No match for candidate 1: Indian Institute of Technology Bombay
# INFO:root:❌ No match for candidate 2: Indian Institute of Technology Roorkee
# INFO:root:❌ No match for candidate 3: Indian Institute of Chemical Technology
# INFO:root:⚠️ No match found, fallback to first candidate: Indian Institute of Technology Bombay
# INFO:root:🔍 Query: MajuLab, CNRS-UNS-NUS-NTU International Joint Research Unit, UMI 3654
# INFO:root:❌ No match for candidate 1: UMI MajuLab
# INFO:root:❌ No match for candidate 2: UCSD-CNRS Joint Research Chemistry Laboratory
# INFO:root:❌ No match for candidate 3: Genetic Improvement and Adaptation of Mediterranean and Tropical Plants
# INFO:root:⚠️ No match found, fallback to first candidate: UMI MajuLab
# INFO:root:🔍 Query: Nanyang Technological - University, Nanyang Technological - University, 1 Nanyang Walk
# INFO:root:❌ No match for candidate 1: Nanyang Technological University
# INFO:root:❌ No match for candidate 2: Xiamen Nanyang University
# INFO:root:❌ No match for candidate 3: Nanyang Normal University
# INFO:root:⚠️ No match found, fallback to first candidate: Nanyang Technological University
# INFO:root:🔍 Query:  50 Nanyang Avenue, Singapore 639798
# INFO:root:❌ No match for candidate 1: Global Health 50/50
# INFO:root:❌ No match for candidate 2: Forum 50%
# INFO:root:❌ No match for candidate 3: Nanyang Polytechnic
# INFO:root:⚠️ No match found, fallback to first candidate: Global Health 50/50
# INFO:root:🔍 Query: Institute of High Performance Computing (IHPC), Agency for Science Technology and Research (A*STAR), 1 Fusionopolis Way
# INFO:root:✅ Match found with candidate 1: Institute of High Performance Computing
# INFO:root:🔍 Query: Centre of Excellence in Quantum Information, Computation, Science and Technology
# INFO:root:❌ No match for candidate 1: Centre for Quantum Computation and Communication Technology
# INFO:root:❌ No match for candidate 2: Quantum Science and Technology in Arcetri
# INFO:root:❌ No match for candidate 3: National Quantum Information Centre in Gdansk
# INFO:root:⚠️ No match found, fallback to first candidate: Centre for Quantum Computation and Communication Technology
# INFO:root:🔍 Query: Guizhou University, Guizhou University, Guiyang 550025
# INFO:root:✅ Match found with candidate 1: Guizhou University
# INFO:root:🔍 Query: Centro Brasileiro de Pesquisas Físicas, Rua Dr. Xavier Sigaud, 150 URCA
# INFO:root:✅ Match found with candidate 1: Centro Brasileiro de Pesquisas Físicas
# INFO:root:🔍 Query: Grupo de investigación “Gravitación, Cosmología, Campos y Cuerdas”
# INFO:root:❌ No match for candidate 1: Grupo Español de Investigación en Neurooncología
# INFO:root:❌ No match for candidate 2: Spanish Research Group on Sarcomas
# INFO:root:❌ No match for candidate 3: Universitaria de Investigación y Desarrollo
# INFO:root:⚠️ No match found, fallback to first candidate: Grupo Español de Investigación en Neurooncología
# INFO:root:🔍 Query: Walailak University, Walailak University, Thasala
# INFO:root:✅ Match found with candidate 1: Walailak University
# INFO:root:🔍 Query: University of KwaZulu–Natal, University of KwaZulu–Natal, Private Bag X54001
# INFO:root:❌ No match for candidate 1: University of KwaZulu-Natal
# INFO:root:❌ No match for candidate 2: KwaZulu-Natal Museum
# INFO:root:❌ No match for candidate 3: Conservancies KZN
# INFO:root:⚠️ No match found, fallback to first candidate: University of KwaZulu-Natal
# INFO:root:🔍 Query: GLA University, GLA University, Mathura-281 406
# INFO:root:✅ Match found with candidate 1: GLA University
# INFO:root:🔍 Query:  Massachusetts Institute of Technology, 77 Massachusetts Avenue
# INFO:root:✅ Match found with candidate 1: Massachusetts Institute of Technology
# INFO:root:🔍 Query: NASA Johnson Space Center, 2101 East NASA Parkway, Houston
# INFO:root:❌ No match for candidate 1: National Aeronautics and Space Administration
# INFO:root:❌ No match for candidate 2: NASA Safety Center
# INFO:root:❌ No match for candidate 3: Ames Research Center
# INFO:root:⚠️ No match found, fallback to first candidate: National Aeronautics and Space Administration
# INFO:root:🔍 Query: NASA Jet Propulsion Laboratory, California Institute of Technology, 4800 Oak Grove Dr
# INFO:root:✅ Match found with candidate 1: Jet Propulsion Laboratory
# INFO:root:🔍 Query: University of Michigan - Michigan Institute for Data Science
# INFO:root:✅ Match found with candidate 1: University of Michigan
# INFO:root:🔍 Query: Ohio State University - Department of Mathematics
# INFO:root:❌ No match for candidate 1: Ohio Department of Agriculture
# INFO:root:❌ No match for candidate 2: Ohio Department of Health
# INFO:root:❌ No match for candidate 3: Ohio Department of Education
# INFO:root:⚠️ No match found, fallback to first candidate: Ohio Department of Agriculture
# INFO:root:🔍 Query: All authors contributed equally to this work.
# INFO:root:❌ No match for candidate 1: Then Try This
# INFO:root:❌ No match for candidate 2: Textbook and Academic Authors Association
# INFO:root:❌ No match for candidate 3: Vessel Work
# INFO:root:⚠️ No match found, fallback to first candidate: Then Try This
# INFO:root:🔍 Query: Address correspondence to: kenreid@umich.edu
# INFO:root:❌ No match for candidate 1: North-West State Technical University
# INFO:root:❌ No match for candidate 2: Russian State Agrarian Correspondence University
# INFO:root:❌ No match for candidate 3: Kutafin Moscow State Law University
# INFO:root:⚠️ No match found, fallback to first candidate: North-West State Technical University
# INFO:root:🔍 Query:  East China Normal University
# INFO:root:✅ Match found with candidate 1: East China Normal University
# INFO:root:🔍 Query: Xiamen University, Xiamen University, Xiamen
# INFO:root:✅ Match found with candidate 1: Xiamen University
# INFO:root:🔍 Query: Astronomical Research Center, Shanghai Science and Technology Museum, Shanghai
# INFO:root:✅ Match found with candidate 1: Shanghai Science and Technology Museum
# INFO:root:🔍 Query: Zhejiang University, Zhejiang University, Hangzhou 310027
# INFO:root:✅ Match found with candidate 1: Zhejiang University
# INFO:root:🔍 Query: Purple Mountain Observatory, 10 Yuan Hua Road, Nanjing 210034
# INFO:root:✅ Match found with candidate 1: Purple Mountain Observatory
# INFO:root:🔍 Query: Center for Computational Astrophysics, Flatiron Institute, 162 5th Ave
# INFO:root:✅ Match found with candidate 1: Flatiron Institute
# INFO:root:🔍 Query:  California Institute of Technology, Pasadena
# INFO:root:✅ Match found with candidate 1: California Institute of Technology
# INFO:root:🔍 Query: LIGO Laboratory, California Institute of Technology, Pasadena
# INFO:root:❌ No match for candidate 1: LIGO Scientific Collaboration
# INFO:root:❌ No match for candidate 2: Jet Propulsion Laboratory
# INFO:root:✅ Match found with candidate 3: California Institute of Technology
# INFO:root:🔍 Query: LIGO Laboratory, Massachusetts Institute of Technology, 185 Albany St
# INFO:root:✅ Match found with candidate 1: Massachusetts Institute of Technology
# INFO:root:🔍 Query:  Massachusetts Institute of Technology, 77 Massachusetts Ave
# INFO:root:✅ Match found with candidate 1: Massachusetts Institute of Technology
# INFO:root:🔍 Query: Stony Brook University, Stony Brook University, Stony Brook NY 11794
# INFO:root:✅ Match found with candidate 1: Stony Brook University
# INFO:root:🔍 Query:  University of Ottawa, Ottawa (ON) K1N 6N5 Canada
# INFO:root:❌ No match for candidate 1: Ottawa University
# INFO:root:✅ Match found with candidate 2: University of Ottawa
# INFO:root:🔍 Query: Shandong University, Shandong University, Jinan 250100
# INFO:root:✅ Match found with candidate 1: Shandong University
# INFO:root:🔍 Query: Shenzhen Research Institute of Shandong University, Shenzhen 518057, China.
# INFO:root:❌ No match for candidate 1: Shenzhen Institute of Building Research (China)
# INFO:root:❌ No match for candidate 2: Shenzhen Research Institute of China University of Geosciences
# INFO:root:❌ No match for candidate 3: Shenzhen University
# INFO:root:⚠️ No match found, fallback to first candidate: Shenzhen Institute of Building Research (China)
# INFO:root:🔍 Query: Perimeter Institute for Theoretical Physics, Waterloo, Ontario
# INFO:root:✅ Match found with candidate 1: Perimeter Institute
# INFO:pylatexenc.latexwalker:Ignoring parse error (tolerant parsing mode): End of input while parsing arguments of macro "\" @(1,137)
# Open LaTeX blocks:
#           @(1,137)  arguments of macro "\"
#
# INFO:root:🔍 Query: JP Morgan Chase
#   jialei.shi, najah.ghalyan, john.buford
# INFO:root:❌ No match for candidate 1: Jozac Publishers
# INFO:root:❌ No match for candidate 2: Chase Foundation
# INFO:root:❌ No match for candidate 3: Parsons School of Design
# INFO:root:⚠️ No match found, fallback to first candidate: Jozac Publishers
# INFO:root:🔍 Query: University of Hawai'i
#  Hilo, University of Hawai'i
#  Hilo, HI 96720
# INFO:root:❌ No match for candidate 1: University of Hawaiʻi at Mānoa
# INFO:root:❌ No match for candidate 2: University of Hawaii at Hilo
# INFO:root:❌ No match for candidate 3: Applied Research Laboratory at the University of Hawai‘i
# INFO:root:⚠️ No match found, fallback to first candidate: University of Hawaiʻi at Mānoa
# INFO:root:🔍 Query: University of Hawai'i
#  Honolulu, University of Hawai'i
#  Honolulu, HI 96822
# INFO:root:❌ No match for candidate 1: University of Hawaiʻi at Mānoa
# INFO:root:❌ No match for candidate 2: Honolulu University
# INFO:root:❌ No match for candidate 3: Chaminade University of Honolulu
# INFO:root:⚠️ No match found, fallback to first candidate: University of Hawaiʻi at Mānoa
# INFO:root:🔍 Query: organization=University of Cambridge, organization=University of Cambridge, Department of Chemical Engineering and Biotechnology
# INFO:root:✅ Match found with candidate 1: University of Cambridge
# INFO:root:🔍 Query: organization=Harvard Medical School, addressline=25 Shattuck Street, city=Boston
# INFO:root:❌ No match for candidate 1: Maple Street School
# INFO:root:❌ No match for candidate 2: Greater Boston Interfaith Organization
# INFO:root:❌ No match for candidate 3: Matthew 25
# INFO:root:⚠️ No match found, fallback to first candidate: Maple Street School
# INFO:root:🔍 Query: organization=Martinos Centre for Biomedical Imaging, Massachusetts General Hospital, addressline=149 13th Street
# INFO:root:❌ No match for candidate 1: Athinoula A. Martinos Center for Biomedical Imaging
# INFO:root:✅ Match found with candidate 2: Massachusetts General Hospital
# INFO:root:🔍 Query: Nanchang Hangkong University, Nanchang Hangkong University, Nanchang
# INFO:root:✅ Match found with candidate 1: Nanchang Hangkong University
# INFO:root:🔍 Query: Nanjing University of Information Science and Technology, Nanjing University of Information Science and Technology, Nanjing
# INFO:root:✅ Match found with candidate 1: Nanjing University of Information Science and Technology
# INFO:root:🔍 Query: The First Affiliated Hospital of Nanchang University, The First Affiliated Hospital of Nanchang University, Nanchang University
# INFO:root:✅ Match found with candidate 1: First Affiliated Hospital of Nanchang University
# ✅ JSON export completed. Results saved to institution_output_with_ror.json

# %%
import json

# 输入文件路径
input_file = "institution_output_with_ror.json"
# 输出文件路径
output_file = "xk_final_affiliations_2000_parallel.json"

# 读取原来的results
with open(input_file, "r", encoding="utf-8") as f:
    original_results = json.load(f)

new_format_results = []

for paper_path, institutions in original_results.items():
    # 去掉前缀，比如 "2311_tex/2311.02188" -> "2311.02188"
    paper_id = paper_path.split('/')[-1]
    
    converted_institutions = []
    for inst in institutions:
        ror_url = inst.get('ROR_ID', '')
        if ror_url.startswith('https://ror.org/'):
            ror_id = ror_url.replace('https://ror.org/', '')
        else:
            ror_id = ror_url  # 防止意外情况

        converted_institutions.append({
            "name": inst.get('Name', 'N/A'),
            "ror_id": ror_id
        })

    new_format_results.append({
        "File ID": paper_id,
        "institutions_with_ror": converted_institutions
    })

# 保存成新的JSON
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(new_format_results, f, indent=2, ensure_ascii=False)

print(f"✅ New prediction file generated: {output_file}")
# Out:
# ✅ New prediction file generated: xk_final_affiliations_2000_parallel.json

# %%
import json

with open("xk_final_affiliations_2000_parallel.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# 统计有多少个 file_id
file_id_count = len(data)

print(f"✅ Total number of File IDs: {file_id_count}")
# Out:
# ✅ Total number of File IDs: 923

# %%
import json

with open('ror/v1.52-2024-09-16-ror-data_schema_v2.json', 'r', encoding='utf-8') as f:
    ror_data = json.load(f)

ror_relationships = {}

for record in ror_data:
    ror_id = record['id']
    related_ids = set()
    for rel in record.get('relationships', []):
        related_ids.add(rel['id'])
    ror_relationships[ror_id] = related_ids

# %%
def is_match(ror1, ror2, ror_relationships):
    related1 = ror_relationships.get(ror1, set())
    related2 = ror_relationships.get(ror2, set())
    return (ror1 == ror2) or (ror2 in related1) or (ror1 in related2)

# %%
import json
import pandas as pd

ground_truth = pd.read_csv("data/2311_with_ror.csv")

with open("institution_output_with_ror.json", 'r', encoding='utf-8') as f:
    extracted_results = json.load(f)

ground_truth['ROR ID'] = ground_truth['ROR ID'].fillna('').astype(str)
ground_truth['paper_id_clean'] = ground_truth['paper_id'].astype(str).str.strip().str.replace(r'v\\d+$', '', regex=True)

gt_rors_per_paper = (
    ground_truth.groupby('paper_id_clean')['ROR ID']
    .apply(lambda x: set(ror.strip() for ror in x if ror.strip() != ''))
    .to_dict()
)

correct_paper_level = 0
total_papers = 0
correct_affiliations = 0
total_affiliations = 0
evaluation_details = []

for paper_id, extracted_rors_list in extracted_results.items():
    paper_id_clean = paper_id.split('/')[-1]
    extracted_rors = set(ror_info['ROR_ID'] for ror_info in extracted_rors_list)
    gt_rors = gt_rors_per_paper.get(str(paper_id_clean), set())

    paper_correct = all(
        any(is_match(gt_ror, extracted_ror, ror_relationships) for extracted_ror in extracted_rors)
        for gt_ror in gt_rors
    ) and all(
        any(is_match(extracted_ror, gt_ror, ror_relationships) for gt_ror in gt_rors)
        for extracted_ror in extracted_rors
    )

    if paper_correct:
        correct_paper_level += 1
    total_papers += 1

    real_missed = []
    for gt_ror in gt_rors:
        total_affiliations += 1
        if any(is_match(gt_ror, extracted_ror, ror_relationships) for extracted_ror in extracted_rors):
            correct_affiliations += 1
        else:
            real_missed.append(gt_ror)

    real_extra = []
    for ext_ror in extracted_rors:
        if not any(is_match(ext_ror, gt_ror, ror_relationships) for gt_ror in gt_rors):
            real_extra.append(ext_ror)

    evaluation_details.append({
        "paper_id": paper_id_clean,
        "ground_truth_rors": list(gt_rors),
        "extracted_rors": list(extracted_rors),
        "matched_affiliations": list(gt_rors.intersection(extracted_rors)),  # optional
        "missed_affiliations": real_missed,
        "extra_affiliations": real_extra,
        "paper_exact_match": paper_correct
    })

paper_level_accuracy = correct_paper_level / total_papers if total_papers > 0 else 0
affiliation_level_accuracy = correct_affiliations / total_affiliations if total_affiliations > 0 else 0

with open("evaluation_details_relationship.json", "w", encoding="utf-8") as f:
    json.dump(evaluation_details, f, indent=4, ensure_ascii=False)

print(f"\n Paper-level accuracy: {paper_level_accuracy * 100:.2f}% ({correct_paper_level}/{total_papers})")
print(f" Affiliation-level accuracy: {affiliation_level_accuracy * 100:.2f}% ({correct_affiliations}/{total_affiliations})")
print(" Detailed evaluation saved to evaluation_details.json")
# Out:
#  Paper-level accuracy: 34.67% (320/923)
#  Affiliation-level accuracy: 66.21% (2242/3386)
#  Detailed evaluation saved to evaluation_details.json
